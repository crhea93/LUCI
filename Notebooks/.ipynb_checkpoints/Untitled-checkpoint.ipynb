# %%
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np

# %%
cube = fits.open('/home/carterrhea/Downloads/NGC1275-Low.fits')
data = cube[0].data
plt.imshow(data[:,:,50])

# %%
data_mean = np.mean(data, axis=(2))

# %%
plt.imshow(data_mean)

# %% [markdown]
# # Plotting Line Functions
# In this notebook we plot the line functions for different broadening values

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
sys.path.insert(0, '/home/carterrhea/Documents/LUCI/')  # Location of Luci
from LUCI.LuciFunctions import SincGauss

# %%
x_ = np.linspace(0, 1000, 1000)
amp_ = 10
pos_ = 500
broads = [10, 20, 30]
sinc_width = 10  # Random but reasonable value

# %%
fig = plt.figure(figsize=(10,8))
for broad_ in broads:
    plt.plot(x_, np.real(SincGauss(x_, [amp_, pos_, broad_], sinc_width).func), label='%i km/s'%broad_)
plt.legend()
# Out:
# /home/carterrhea/Documents/LUCI/LUCI/LuciFunctions.py:38: RuntimeWarning: invalid value encountered in add
#   self.func = p0*np.exp(-b**2)*((erf1+erf2)/erf3)
# /home/carterrhea/Documents/LUCI/LUCI/LuciFunctions.py:38: RuntimeWarning: invalid value encountered in true_divide
#   self.func = p0*np.exp(-b**2)*((erf1+erf2)/erf3)

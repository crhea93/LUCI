# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import fits
from IPython.display import display, Math
from scipy.optimize import minimize
import astropy.units as u
from astropy.modeling.models import custom_model
from scipy import interpolate
import keras
from scipy.optimize import Bounds
import sys
sys.path.insert(0, '/home/carterrhea/Documents/LUCI/')  # Location of Luci
import LUCI.LuciFit as lfit
import emcee
import corner

# %%
# Read in Data

sigma_info = []
velocity_info = []
res_info = []
spectrum = fits.open('../Data/Reference-Spectrum-R5000.fits')
header = spectrum[0].header
spec = spectrum[1].data
channel = []
counts = []
for chan in spec:
    channel.append(chan[0])
    counts.append(chan[1])

axis = channel
sky = counts
velocity = header['VELOCITY']
sigma = header['BROADEN']
print(velocity, sigma)
# Out:
# 0 10

# %%
# Machine Learning Reference Spectrum
ref_spec = fits.open('../ML/Reference-Spectrum-R5000.fits')[1].data
channel = []
counts = []
for chan in ref_spec:  # Only want SN3 region
    channel.append(chan[0])
    counts.append(np.real(chan[1]))
min_ = np.argmin(np.abs(np.array(channel)-14700))
max_ = np.argmin(np.abs(np.array(channel)-15600))
wavenumbers_syn = channel[min_:max_]

# %%
f = interpolate.interp1d(axis, sky, kind='slinear')
sky_corr = (f(wavenumbers_syn))
sky_corr_scale = np.max(sky_corr)
sky_corr = sky_corr/sky_corr_scale
print(sky_corr.shape)
# Out:
# (460,)

# %%
plt.plot(wavenumbers_syn, sky_corr)

# %%
fit = lfit.Fit(sky, axis, wavenumbers_syn, 'sinc', ['Halpha', 'NII6583', 'NII6548','SII6716', 'SII6731'], [1,1,1,1,1], [1,1,1,2,2],
                keras.models.load_model('../ML/R5000-PREDICTOR-I'),
                 Plot_bool = False, bayes_bool=False)
fit_dict = fit.fit()
print(fit_dict['velocities'])
print(fit_dict['fit_sol'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'numpy.ndarray' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a944215bf1dd> in <module>
#       2                 keras.models.load_model('../ML/R5000-PREDICTOR-I'),
#       3                  Plot_bool = False, bayes_bool=False)
# ----> 4 fit_dict = fit.fit()
#       5 print(fit_dict['velocities'])
#       6 print(fit_dict['fit_sol'])
#
# ~/Documents/LUCI/LUCI/LuciFit.py in fit(self)
#     568             self.spectrum_scale = np.max(self.spectrum)
#     569         # Apply Fit
# --> 570         self.calculate_params()
#     571         # Check if Bayesian approach is required
#     572         if self.bayes_bool == True:
#
# ~/Documents/LUCI/LUCI/LuciFit.py in calculate_params(self)
#     417         # Calculate uncertainties using the negative inverse hessian  as the covariance matrix
#     418         hessian = Hessian(nll)
# --> 419         hessian_calc = hessian([parameters, self.noise])
#     420         print(hessian_calc)
#     421         exit()
#
# ~/miniconda3/envs/luci/lib/python3.9/site-packages/numdifftools/core.py in __call__(self, x, *args, **kwds)
#     536
#     537     def __call__(self, x, *args, **kwds):
# --> 538         return super(Hessdiag, self).__call__(np.atleast_1d(x), *args, **kwds)
#     539
#     540
#
# ~/miniconda3/envs/luci/lib/python3.9/site-packages/numdifftools/core.py in __call__(self, x, *args, **kwds)
#     286         x_i = np.asarray(x)
#     287         with np.errstate(divide='ignore', invalid='ignore'):
# --> 288             results, f_xi = self._derivative(x_i, args, kwds)
#     289             derivative, info = self._extrapolate(*results)
#     290         if self.full_output:
#
# ~/miniconda3/envs/luci/lib/python3.9/site-packages/numdifftools/core.py in _derivative_nonzero_order(self, x_i, args, kwds)
#     234     def _derivative_nonzero_order(self, x_i, args, kwds):
#     235         diff, f = self._get_functions(args, kwds)
# --> 236         steps, step_ratio = self._get_steps(x_i)
#     237         fxi = self._eval_first(f, x_i)
#     238         results = [diff(f, fxi, x_i, h) for h in steps]
#
# ~/miniconda3/envs/luci/lib/python3.9/site-packages/numdifftools/core.py in _get_steps(self, x_i)
#     262         method, n, order = self.method, self.n, self.method_order
#     263         # pylint: disable=no-member
# --> 264         step_gen = self.step.step_generator_function(x_i, method, n, order)
#     265         return list(step_gen()), step_gen.step_ratio
#     266
#
# ~/miniconda3/envs/luci/lib/python3.9/site-packages/numdifftools/step_generators.py in step_generator_function(self, x, method, n, order)
#     276         """Step generator function"""
#     277         self._state = _STATE(np.asarray(x), method, n, order)
# --> 278         base_step, step_ratio = self.base_step * self.step_nom, self.step_ratio
#     279         if self.use_exact_steps:
#     280             base_step = make_exact(base_step)
#
# ~/miniconda3/envs/luci/lib/python3.9/site-packages/numdifftools/step_generators.py in step_nom(self)
#     266         x = self._state.x
#     267         if self._step_nom is None:
# --> 268             return get_nominal_step(x)
#     269         return np.full(x.shape, fill_value=self._step_nom)
#     270
#
# ~/miniconda3/envs/luci/lib/python3.9/site-packages/numdifftools/step_generators.py in get_nominal_step(x)
#      26     if x is None:
#      27         return 1.0
# ---> 28     return np.log(1.718281828459045 + np.abs(x)).clip(min=1)
#      29
#      30
#
# TypeError: loop of ufunc does not support argument 0 of type numpy.ndarray which has no callable log method

# %%
plt.plot(axis, sky)
plt.plot(axis, fit_dict['fit_vector'])
